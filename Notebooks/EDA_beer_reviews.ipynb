# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('../Data/Clean/beer_reviews_all_columns.csv')

# %%
df.columns
# Out:
# Index(['review_overall', 'review_aroma', 'review_appearance', 'beer_style',
#        'review_palate', 'review_taste', 'year'],
#       dtype='object')

# %%
df.groupby(df['beer_style'])[['review_overall', 'review_aroma', 'review_appearance', 'review_palate', 'review_taste']].mean().round(2)
# Out:
#             review_overall  review_aroma  review_appearance  review_palate  \
# beer_style
# 1                     3.77          3.66               3.84           3.69
# 2                     3.57          3.27               3.59           3.44
# 3                     3.88          3.98               4.01           3.95
# 4                     3.92          3.91               4.10           3.89
# 5                     3.84          3.77               3.88           3.75
# 6                     3.60          3.33               3.57           3.58
# 7                     3.90          3.86               3.96           3.80
# 8                     3.45          3.14               3.38           3.36
# 9                     4.04          4.14               4.14           4.07
# 10                    3.96          3.96               4.01           3.92
# 11                    2.98          2.54               2.87           2.82
# ...

# %%
df_beers_data=pd.read_csv('../Data/Clean/standard_beer_types_features_clean.csv')

# %%
df_beers_data[df_beers_data['style_id']==10]
# Out:
#                 beer_style color bitterness  alcohol  style_id
# 9  american india pale ale  Gold       High  Regular        10

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 503104 entries, 0 to 503103
# Data columns (total 7 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   review_overall     503104 non-null  float64
#  1   review_aroma       503104 non-null  float64
#  2   review_appearance  503104 non-null  float64
#  3   style_id           503104 non-null  int64
#  4   review_palate      503104 non-null  float64
#  5   review_taste       503104 non-null  float64
#  6   year               503104 non-null  int64
# dtypes: float64(5), int64(2)
# memory usage: 26.9 MB

# %%
df_beers_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72 entries, 0 to 71
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   beer_style  72 non-null     object
#  1   color       72 non-null     object
#  2   bitterness  72 non-null     object
#  3   alcohol     72 non-null     object
#  4   style_id    72 non-null     int64
# dtypes: int64(1), object(4)
# memory usage: 2.9+ KB
